# %% [markdown]
# <br></br>
# <br></br>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="
#             webkit-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             moz-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(101, 185, 249);">
#     <br>
#     <h6 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><i class="fa fa-database fa-1.5x" aria-hidden="false"></i> !!-- PostgreSQL Implementation --!!
#     </h6>
#     <br>
#     </div>
# </div>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="
#             webkit-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             moz-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(243, 116, 99);">
#     <br>
#         <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><i class="fa fa-folder" aria-hidden="true"></i> Directory Guide</h1>
#         <pre class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(232, 219, 217);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# <b><i class="fa fa-folder" aria-hidden="true"></i> PostgreSQL Implementation</b>
# + |
# | +
# + |--> <i class="fa fa-folder" aria-hidden="true"></i> <b>Current Employee Analysis</b>
# | +      |
# + |      +
# | +      |--> Aggregated dashboard views.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +      |--> Current Analysis.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +      |--> Current Employee Snapshot.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +      |--> Current vs Historic (Georgi’s Salary Comparison).sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +      |--> Department Level Dashboard.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +
# + |
# | +
# + |--> <i class="fa fa-folder" aria-hidden="true"></i> <b>Exploring Data</b>
# | +      |
# + |      +
# | +      |--> EDA.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +      |--> query_create_materialized_views.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +      |--> Valid Data Points.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +
# + |
# | +
# + |
# | +
# + |--> <i class="fa fa-folder" aria-hidden="true"></i> <b>Historic Employee Analysis</b>
# | +      |
# + |      +
# | +      |--> Employee Churn.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +      |--> Historic Employee Deep Dive View.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +
# + |
# | +
# + |--> <i class="fa fa-folder" aria-hidden="true"></i> <b>data</b>
# | +      |
# + |      +
# | +      |--> historic_employees_analysis.csv <i class="fa fa-file-excel-o" aria-hidden="false"></i>
# + |      +
# | +      |--> current_employee_snapshot.csv <i class="fa fa-file-excel-o" aria-hidden="false"></i>
# + |      +
# | +      |--> department.csv <i class="fa fa-file-excel-o" aria-hidden="false"></i>
# + |      +
# | +      |--> department_employee.csv <i class="fa fa-file-excel-o" aria-hidden="false"></i>
# + |      +
# | +      |--> department_manager.csv <i class="fa fa-file-excel-o" aria-hidden="false"></i>
# + |      +
# | +      |--> employee.csv <i class="fa fa-file-excel-o" aria-hidden="false"></i>
# + |      +
# | +      |--> salary.csv <i class="fa fa-file-excel-o" aria-hidden="false"></i>
# + |      +
# | +      |--> title.csv <i class="fa fa-file-excel-o" aria-hidden="false"></i>
# + |      +
# | +
# + |
# | +
# + |--> <i class="fa fa-folder" aria-hidden="true"></i> <b>Implementing Joins</b>
# | +      |
# + |      +
# | +      |--> current_join_table.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +      |--> naive_join_table.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria- hidden="false"></i>
# + |      +
# | +
# + |
# | +
# + |
# | +
# + |--> <i class="fa fa-folder" aria-hidden="true"></i> <b>markdown</b>
# | +      |
# + |      +
# | +      |--> <i class="fa fa-folder" aria-hidden="false"></i> <b>.ipynb_checkpoints</b>
# + |      +
# | +      |--> EDA_PostgreSQL.ipynb <i class="fa fa-file-code-o" aria-hidden="false"></i>
# + |      +
# | +      |--> query_create_tables.ipynb <i class="fa fa-file-code-o" aria-hidden="false"></i>
# + |      +
# | +
# + |
# | +
# + |--> Management Analysis.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria-hidden="false"></i>
# | +
# + |--> query_create_tables.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria-hidden="false"></i>
# | +
# + |--> Salary Benchmark Views.sql <i class="fa fa-file-code-o" aria-hidden="true"></i> <i class="fa fa-database fa-1.5x" aria-hidden="false"></i>
# | +
# +
# |
# +
# </pre><br>
#     </div>
# </div>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="
#             webkit-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             moz-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(243, 116, 99);">
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"> Context</h1>
#     <p class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(232, 219, 217);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# <b>DATASET:</b> For this case study, <b>"employees"</b> dataset will be used to illustrate/demonstrate implementation of re-usable data assets along with other concepts like Snapshot and Historic Data that will be used for data analysis. However, This section ONLY covers the EDA part.<br><br>
# <b>BUSINESS PROBLEM:</b><br>
# As stated by Danny himself:<br>
# <br><i class="fa fa-quote-left fa-3x fa-pull-left fa-border-black" aria-hidden="false"></i>
# All of the data required for this case study lives within the <b>employees schema</b> within our Docker environment, however there is one glaring issue with all of the data…
# The <b>date fields</b> in the HR Analytica tables were accidentally input with <b>incorrect year</b> values due to a young intern accidentally messing up their data entry process!
# We will definitely need to fix this data issue before we start tackling the business requirements from HR Analytica.
# <br><br>
# There is the issue with the dates where our young unlucky intern <b>accidentally input the year which is 18 years behind</b> what it should be.<br>
# so we will need to keep an eye on this one as we think about our data solutions for the case study!
# <i class="fa fa-quote-right fa-3x fa-pull-right fa-border-black" aria-hidden="false"><br></i>
# <br>
# <br>
# <br>
# (No wonder why they don't hire interns/freshers like me)
# <br>
#     </p>
#     <br>
#     <br>
#         <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><i class="fa fa-exclamation-triangle" aria-hidden="false"></i> Approach</h1>
#         <p class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(232, 219, 217);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# Given the nature of data -AND- the nature of problem at hand, An Exploratory Analysis is required to make amends.
# This section describes the Dataset which has been specifically provided for this case study, Covering a range of steps to be followed while performing basic Exploratory data analysis, while at the same time making amends in data values.
#         <br>
#     </p><br>
#     </div>
# </div>

# %% [markdown]
# <br></br>
# <br></br>
# <br></br>

# %% [markdown]
# <p style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 6px double #000;
#                 background-color: rgb(219, 242, 188);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 790px;
#                 margin-right: 1px;
#                 margin-bottom: 10px;
#                ">
# <i class="fa fa-window-maximize fa-pull-center fa-2x" aria-hidden="true"></i> <i class="fa fa-window-minimize fa-pull-left fa-2x" aria-hidden="true"></i> <i class="fa fa-window-close-o fa-pull-right fa-2x" aria-hidden="true"></i>
# <br>
# </p>

# %% [markdown]
# ![EDA_header_2.PNG](attachment:EDA_header_2.PNG)

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="
#             -webkit-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             -moz-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             box-shadow: 10px 10px 0px 0px  rgba(0, 0, 0, 0.59);
#             background-color: rgb(255, 195, 0);">
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><b><i class="fa fa-file-text" aria-hidden="false"></i>
# FILE NAME/DATASET:</b> <br></h1>
#     <p class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(239, 234, 175);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
#         <br><i class="fa fa-file-excel-o" aria-hidden="false"></i>
#  department.csv<br>
#         <br><i class="fa fa-file-excel-o" aria-hidden="false"></i>
#  department_employee.csv<br>
#         <br><i class="fa fa-file-excel-o" aria-hidden="false"></i>
#  department_manager.csv<br>
#         <br><i class="fa fa-file-excel-o" aria-hidden="false"></i>
#  employee.csv<br>
#         <br><i class="fa fa-file-excel-o" aria-hidden="false"></i>
#  salary.csv<br>
#         <br><i class="fa fa-file-excel-o" aria-hidden="false"></i>
#  title.csv<br>
#     </p>
#     <br>
# <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><b><i class="fa fa-table" aria-hidden="false"></i>
# Data Summary:</b> <br></h1>
#      <pre class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 padding-right: 1px;
#                 border: 4px solid #000;
#                 background-color: rgb(239, 234, 175);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 310px;
#                 margin-bottom: 10px;
#                ">
#                <br>
# <b>||-- Column Count --||</b><br>
#            <i class="fa fa-th fa-2x" aria-hidden="true"></i>              <i class="fa fa-columns fa-2x" aria-hidden="true"></i>
# +---------------------+---------------+
# |<b>table_name </b>          |<b>column_count </b>  |
# +---------------------+---------------+
# | department          | 2             |
# | department_employee | 4             |
# | department_manager  | 4             |
# | employee            | 6             |
# | salary              | 4             |
# | title               | 4             |
# +---------------------+---------------+
#                <br>
# <b>||-- Table Size --||</b><br>
#            <i class="fa fa-th fa-2x" aria-hidden="true"></i>              <i class="fa fa-columns fa-2x" aria-hidden="true"></i>
# +---------------------+-------------+
# | <b>table_name</b>          | <b>table_size</b>  |
# +---------------------+-------------+
# | employee            | 20 MB       |
# | department_employee | 17 MB       |
# | department          | 8,192 bytes |
# | department_manager  | 8,192 bytes |
# | salary              | 142 MB      |
# | title               | 25 MB       |
# +---------------------+-------------+
#                <br>
# <b>||-- Row Count --||</b><br>
#            <i class="fa fa-th fa-2x" aria-hidden="true"></i>              <i class="fa fa-sort-numeric-desc fa-2x" aria-hidden="true"></i>
# +---------------------+---------------+
# | <b>_table_name_</b>        | <b>total_records</b> |
# +---------------------+---------------+
# | salary              | 2,844,050     |
# | title               | 443,308       |
# | department_employee | 331,603       |
# | employee            | 300,024       |
# | department_manager  | 24            |
# | department          | 9             |
# +---------------------+---------------+
#                <br>
# <b>||-- Overall dataset measures --||</b>
# +----------------+------------------+
# | <b>dimension_name</b> | <b>aggregated_value</b> |
# +----------------+------------------+
# | row_count      | 3,919,018        |
# | column_count   | 24               |
# +----------------+------------------+
#                <br>
# </pre>
# <br>
#     </div>
# </div>

# %% [markdown]
# ![ER_Diagram_word_doc-1.png](attachment:ER_Diagram_word_doc-1.png)

# %% [markdown]
# <br></br>
# <br></br>
# <br></br>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="
#             webkit-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             moz-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(200, 300, 10);">
#     <br>
#     <br>
#     <p class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(219, 242, 188);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
#         <b><i class="fa fa-table fa-1.8x fa-pull-centre" aria-hidden="false"></i> Database Tables Overview</b><br>
#     </p>
#     <br>
#     </div>
# </div>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(200, 201, 20);">
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><i class="fa fa-file-code-o fa-2x fa-pull-between" aria-hidden="true"></i>
#  QUERY</h1>
#     <pre class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(230, 234, 206 );
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                 color:dark-grey;
#                ">
# --Overview of each table
# --Table: "employee"
# SELECT
# 	id,
# 	hire_date,
# 	(hire_date + INTERVAL '18 YEARS')::DATE AS adjusted_hire_date
# FROM employee
# WHERE hire_date <> '9999-01-01'::DATE
# LIMIT 5;
#
#
# --Table: "title"
# SELECT
# 	*
# FROM title
# WHERE employee_id = 10005
# ORDER BY from_Date ASC;
#
#
# --Table: "salary"
# SELECT
# 	*,
# 	(to_date + INTERVAL '18 YEARS')::DATE AS adjusted_to_date
# FROM salary
# WHERE to_date <> '9999-01-01'
# ORDER BY from_Date ASC
# LIMIT 5;
#
#
# --Table: "department_employee"
# SELECT
# 	*,
# 	(to_date + INTERVAL '18 YEARS')::DATE AS adjusted_to_date
# FROM department_employee
# WHERE to_date <> '9999-01-01'
# ORDER BY from_Date ASC
# LIMIT 5;
#
#
# --Table: "department"
# SELECT *
# FROM department;
#
#
# --Table: "department_manager"
# SELECT
# 	*,
# 	(to_date + INTERVAL '18 YEARS')::DATE AS adjusted_to_date
# FROM department_manager
# WHERE to_date <> '9999-01-01'
# ORDER BY from_Date ASC;
#     </pre>
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"> QUERY RESULTS</h1>
#     <pre class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 padding-right: 1px;
#                 border: 4px solid #000;
#                 background-color: rgb(230, 234, 206);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# <b>|| employee ||</b><br>
#              <i class="fa fa-calendar-times-o fa-2x" aria-hidden="true"></i>            <i class="fa fa-calendar-check-o fa-2x" aria-hidden="true"></i>
# +-------+------------+--------------------+
# | <b>id</b>    | <b>hire_date</b>  | <b>adjusted_hire_date</b> |
# +-------+------------+--------------------+
# | 10001 | 1986-06-26 | 2004-06-26         |
# | 10002 | 1985-11-21 | 2003-11-21         |
# | 10003 | 1986-08-28 | 2004-08-28         |
# | 10004 | 1986-12-01 | 2004-12-01         |
# | 10005 | 1989-09-12 | 2007-09-12         |
# +-------+------------+--------------------+
# <br>
# <br>
# <b>|| title ||</b><br>
#                                    <i class="fa fa-calendar-times-o fa-2x" aria-hidden="true"></i>         <i class="fa fa-calendar-times-o fa-2x" aria-hidden="true"></i>
# +-------------+--------------+------------+------------+
# | <b>employee_id</b> | <b>title</b>        | <b>from_date</b>  | <b>to_date</b>    |
# +-------------+--------------+------------+------------+
# | 10005       | Staff        | 1989-09-12 | 1996-09-12 |
# | 10005       | Senior Staff | 1996-09-12 | 9999-01-01 |
# +-------------+--------------+------------+------------+
# <br>
# <br>
# <b>|| salary ||</b><br>
#                               <i class="fa fa-calendar-times-o fa-2x" aria-hidden="true"></i>          <i class="fa fa-calendar-times-o fa-2x" aria-hidden="true"></i>              <i class="fa fa-calendar-check-o fa-2x" aria-hidden="true"></i>
# +-------------+----------+-------------+------------+--------------------+
# | <b>employee_id</b> | <i class="fa fa-usd" aria-hidden="true"></i><b> amount</b> | <b>from_date</b>   | <b>to_date</b>    |<b>adjusted_to_date</b>    |
# +-------------+----------+-------------+------------+--------------------+
# | 110183      | 48,291   | 1985-01-01  | 1986-01-01 | 2004-01-01         |
# | 110303      | 42,093   | 1985-01-01  | 1986-01-01 | 2004-01-01         |
# | 110085      | 60,026   | 1985-01-01  | 1986-01-01 | 2004-01-01         |
# | 110022      | 71,166   | 1985-01-01  | 1986-01-01 | 2004-01-01         |
# | 110511      | 48,626   | 1985-01-01  | 1986-01-01 | 2004-01-01         |
# +-------------+----------+-------------+------------+--------------------+
# <br>
# <br>
# <b>|| department_employee ||</b><br>
#                                    <i class="fa fa-calendar-times-o fa-2x" aria-hidden="true"></i>         <i class="fa fa-calendar-times-o fa-2x" aria-hidden="true"></i>            <i class="fa fa-calendar-check-o fa-2x" aria-hidden="true"></i>
# +-------------+---------------+------------+------------+------------------+
# | <b>employee_id</b> | <b>department_id</b> | <b>from_date</b>  | <b>to_date</b>    | <b>adjusted_to_date</b> |
# +-------------+---------------+------------+------------+------------------+
# | 235233      | d004          | 1985-02-01 | 1998-08-23 | 2016-08-23       |
# | 204308      | d004          | 1985-02-02 | 1993-07-14 | 2011-07-14       |
# | 43969       | d005          | 1985-02-02 | 1992-09-13 | 2010-09-13       |
# | 32293       | d005          | 1985-02-02 | 1996-07-22 | 2014-07-22       |
# | 109137      | d004          | 1985-02-02 | 1996-08-06 | 2014-08-06       |
# +-------------+---------------+------------+------------+------------------+
#     </pre>
#     <br>
#     </div>
# </div>

# %% [markdown]
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="
#             webkit-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             moz-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(243, 116, 99);">
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"> Fixing Data values</h1>
#     <p class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(232, 219, 217);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# <b>Option 1 - Permanent Tables:</b><br>For our first option of creating new permanent tables - we saw that creating adjusted permanent tables is not so ideal when there is new data coming in on a regular basis.We would need to perform one of the following to regularly maintain these datasets:
# <br><br>
# <i class="fa fa-chevron-right" aria-hidden="true"></i> Drop the previous created table and replace it with a new table when new data is updated
#         <br>
#         <b>-OR-</b>
#         <br>
# <i class="fa fa-chevron-right" aria-hidden="true"></i> Design a complex update and insert strategy whenever there are changes in the upstream source data.<br>
# Would not proceed with since Indexes are not retained.
# <br>
# <br>
# <br>
# <b>Option 2 - Views:</b><br>
# Retaining all the underlying index information from our source data references and also giving us access to any updates in the upstream data too. Would not proceed due to excessive computational costs.
# <br>
# <br>
# <b>Option 3 - Materialized Views:</b><br>
# Indexes are recreated from scratch each time the view is refreshed without any further intervention.
# Need to refresh Materialized Views after performing update, NOT a perfect solution, but works for this scenario.
# <br>
# <br>
#     </p>
#     <br>
#     <br>
#         <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><i class="fa fa-exclamation-triangle" aria-hidden="false"></i> Approach</h1>
#         <p class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(232, 219, 217);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# <b>Option 1 - Permanent Tables: </b><i class="fa fa-times-circle-o fa-1x" aria-hidden="true"></i>
# <br>
# <b>Option 2 - Views: </b><i class="fa fa-times-circle-o fa-1x" aria-hidden="true"></i>
# <br>
# <b>Option 3 - Materialized Views: </b><i class="fa fa-thumbs-up" aria-hidden="true"></i>
# <br>
#     </p><br>
#     </div>
# </div>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(200, 201, 20);">
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><i class="fa fa-file-code-o fa-2x fa-pull-between" aria-hidden="true"></i>
#  QUERY (Create Materialized Views)</h1>
#     <pre class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(230, 234, 206 );
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                 color:dark-grey;
#                ">
# DROP SCHEMA IF EXISTS mv_employees CASCADE;
# CREATE SCHEMA mv_employees;
#
#
#
# DROP MATERIALIZED VIEW IF EXISTS mv_employees.mv_department;
# CREATE MATERIALIZED VIEW mv_employees.mv_department AS
# SELECT *
# FROM department;
#
#
# DROP MATERIALIZED VIEW IF EXISTS mv_employees.mv_department_employee;
# CREATE MATERIALIZED VIEW mv_employees.mv_department_employee AS
# SELECT
# 	employee_id,
# 	department_id,
# 	(from_date + INTERVAL '18 YEARS')::DATE AS from_date,
# 	CASE
# 	WHEN to_date <> '9999-01-01'::DATE THEN (to_date + INTERVAL '18 YEARS')::DATE
# 	ELSE to_date
# 	END AS to_date
# FROM department_employee;
#
#
# DROP MATERIALIZED VIEW IF EXISTS mv_employees.mv_department_manager;
# CREATE MATERIALIZED VIEW mv_employees.mv_department_manager AS
# SELECT
# 	employee_id,
# 	department_id,
# 	(from_date + INTERVAL '18 YEARS')::DATE AS from_date,
# 	CASE
# 	WHEN to_date <> '9999-01-01'::DATE THEN (to_date + INTERVAL '18 YEARS')::DATE
# 	ELSE to_date
# 	END AS to_date
# FROM department_manager;
#
#
# DROP MATERIALIZED VIEW IF EXISTS mv_employees.mv_employee;
# CREATE MATERIALIZED VIEW mv_employees.mv_employee AS
# SELECT
# 	id,
# 	(birth_date + INTERVAL '18 YEARS')::DATE AS birth_date,
# 	first_name,
# 	last_name,
# 	gender,
# 	(hire_date + INTERVAL '18 YEARS')::DATE AS hire_date
# FROM employee;
#
#
# DROP MATERIALIZED VIEW IF EXISTS mv_employees.mv_salary;
# CREATE MATERIALIZED VIEW mv_employees.mv_salary AS
# SELECT
# 	employee_id,
# 	amount,
# 	(from_date + INTERVAL '18 YEARS')::DATE AS from_date,
# 	CASE
# 	WHEN to_date <> '9999-01-01'::DATE THEN (to_date + INTERVAL '18 YEARS')::DATE
# 	ELSE to_date
# 	END AS to_date
# FROM salary;
#
#
# DROP MATERIALIZED VIEW IF EXISTS mv_employees.mv_title;
# CREATE MATERIALIZED VIEW mv_employees.mv_title AS
# SELECT
# 	employee_id,
# 	title,
# 	(from_date + INTERVAL '18 YEARS')::DATE AS from_date,
# 	CASE
# 	WHEN to_date <> '9999-01-01'::DATE THEN (to_date + INTERVAL '18 YEARS')::DATE
# 	ELSE to_date
# 	END AS to_date
# FROM title;
#
# CREATE INDEX ON mv_employees.mv_salary (employee_id);
# REFRESH MATERIALIZED VIEW mv_employees.mv_salary;
#
# EXPLAIN ANALYZE
# SELECT *
# FROM mv_employees.mv_salary
# WHERE mv_salary.employee_id = 10001;
# <br>
# <br>
# </pre>
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"> QUERY RESULTS</h1>
#     <pre class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 padding-right: 1px;
#                 border: 4px solid #000;
#                 background-color: rgb(230, 234, 206);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# +-------------------------------------------------------------------------------+
# | <b>QUERY PLAN</b>                                                                    |
# +-------------------------------------------------------------------------------+
# | Index Scan using mv_salary_employee_id_idx on mv_salary                       |
# |            >(<b>cost</b> = 0.43..8.62 <b>rows</b> = 11 <b>width</b> = 24)                          |
# |            >(<b>actual time</b> = 0.045..0.047 <b>rows</b> = 17 <b>loops</b> = 1)                  |
# +-------------------------------------------------------------------------------+
# | <b>Index Cond:</b> (employee_id = 10001)                                             |
# +-------------------------------------------------------------------------------+
# | <b>Planning Time:</b> 0.330 ms                                                       |
# +-------------------------------------------------------------------------------+
# | <b>Execution Time:</b> 0.057 ms                                                      |
# +-------------------------------------------------------------------------------+
#     </pre>
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;">
#         <i class="fa fa-file-code-o fa-2x fa-pull-between" aria-hidden="true"></i> INDEXES</h1>
#     <pre class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 padding-right: 1px;
#                 border: 4px solid #000;
#                 background-color: rgb(230, 234, 206);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# CREATE UNIQUE INDEX
#     ON mv_employees.mv_employee USING btree (id);
#
# CREATE UNIQUE INDEX
#     ON mv_employees.mv_department_employee USING btree (employee_id, department_id);
#
# CREATE INDEX
#     ON mv_employees.mv_department_employee USING btree (department_id);
#
# CREATE UNIQUE INDEX
#     ON mv_employees.mv_department USING btree (id);
#
# CREATE UNIQUE INDEX
#     ON mv_employees.mv_department USING btree (dept_name);
#
# CREATE UNIQUE INDEX
#     ON mv_employees.mv_department_manager USING btree (employee_id, department_id);
#
# CREATE INDEX
#     ON mv_employees.mv_department_manager USING btree (department_id);
#
# CREATE UNIQUE INDEX
#     ON mv_employees.mv_salary USING btree (employee_id, from_date);
#
# CREATE UNIQUE INDEX
#     ON mv_employees.mv_title USING btree (employee_id, title, from_date);
# </pre>
# <br>
#     </div>
# </div>
#     <br>
#     </div>
# </div>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(200, 201, 20);">
#     <br>
#     <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><i class="fa fa-table fa-2x fa-pull-between" aria-hidden="true"></i> <i class="fa fa-exchange fa-2x" aria-hidden="true"></i> <i class="fa fa-table fa-2x fa-pull-between" aria-hidden="true"></i>
#  COMPLETE AND NAIVE Joins</h1>
#     <pre class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(230, 234, 206 );
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                 color:dark-grey;
#                ">
# <b>--Retains duplicate records</b>
# DROP TABLE IF EXISTS naive_join_table;
# CREATE TEMP TABLE naive_join_table AS
# SELECT
# 	--Table: mv_employee
# 	mv_employee.id,
# 	mv_employee.birth_date,
# 	mv_employee.first_name,
# 	mv_employee.last_name,
# 	mv_employee.gender,
# 	mv_employee.hire_date,
# 	--Table: mv_title
# 	mv_title.title,
# 	mv_title.from_date AS title_from_date,
# 	mv_title.to_date AS title_to_date,
# 	--Table: mv_salary
# 	mv_salary.amount AS salary_amount,
# 	mv_salary.from_date AS salary_from_date,
# 	mv_salary.to_date AS salary_to_date,
# 	--Table: mv_department_employee
# 	mv_department_employee.department_id,
# 	mv_department.dept_name,
# 	mv_department_employee.from_date AS dept_from_date,
# 	mv_department_employee.to_date AS dept_to_date
# FROM mv_employees.mv_employee
# INNER JOIN mv_employees.mv_salary
# 	ON mv_employee.id = mv_salary.employee_id
# INNER JOIN mv_employees.mv_department_employee
# 	ON mv_employee.id = mv_department_employee.employee_id
# INNER JOIN mv_employees.mv_title
# 	ON mv_employee.id = mv_title.employee_id
# INNER JOIN mv_employees.mv_department
# 	ON mv_department_employee.department_id = mv_department.id;
#
#
#
# <b>--Does not retains duplicate records</b>
# DROP TABLE IF EXISTS current_join_table;
# CREATE TEMP TABLE current_join_table AS
# SELECT
# 	--Table: mv_employee
# 	mv_employee.id,
# 	mv_employee.birth_date,
# 	mv_employee.first_name,
# 	mv_employee.last_name,
# 	mv_employee.gender,
# 	mv_employee.hire_date,
# 	--Table: mv_title
# 	mv_title.title,
# 	mv_title.from_date AS title_from_date,
# 	mv_title.to_date AS title_to_date,
# 	--Table: mv_salary
# 	mv_salary.amount AS salary_amount,
# 	mv_salary.from_date AS salary_from_date,
# 	mv_salary.to_date AS salary_to_date,
# 	--Table: mv_department_employee
# 	mv_department_employee.department_id,
# 	mv_department.dept_name,
# 	mv_department_employee.from_date AS dept_from_date,
# 	mv_department_employee.to_date AS dept_to_date
# FROM mv_employees.mv_employee
# INNER JOIN mv_employees.mv_salary
# 	ON mv_employee.id = mv_salary.employee_id
# INNER JOIN mv_employees.mv_department_employee
# 	ON mv_employee.id = mv_department_employee.employee_id
# INNER JOIN mv_employees.mv_title
# 	ON mv_employee.id = mv_title.employee_id
# INNER JOIN mv_employees.mv_department
# 	ON mv_department_employee.department_id = mv_department.id
# WHERE
# 	mv_title.to_date = '9999-01-01'
# 	AND
# 	mv_salary.to_date = '9999-01-01'
# 	AND
# 	mv_department_employee.to_date = '9999-01-01';
# <br>
# </pre>
#     <br>
#     <br>
#     </div>
# </div>
#     <br>
#     </div>
# </div>

# %% [markdown]
# <br></br>
# <br></br>
# <br></br>

# %% [markdown]
# <div id="box-shadow-panel">
# <div id="box-shadow-object"
#      style="
#             webkit-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             moz-box-shadow: 10px 10px 0px 0px rgba(0,0,0,0.52);
#             box-shadow: rgba(0, 0, 0, 0.69) 10px 10px 0px 3px;
#             background-color: rgb(243, 116, 99);">
#     <br>
#         <h1 style = "
#             webkit-text-size-adjust: 100%;
#             font-family: Lucida Sans Typewriter,Lucida Console,monaco,Bitstream Vera Sans Mono,monospace;
#             font-weight: bold;
#             font-size: 2.25rem;
#             margin-left: 10px;
#             line-height: 0.9;
#             margin-top: 10.5px;
#             margin-left: 18px;
#             box-sizing: border-box;"><i class="fa fa-id-card-o" aria-hidden="true"></i> Social Credentials</h1>
#     <br>
#     <a class="w-para" href="https://www.linkedin.com/in/yogesh-dagar-359043212/">
#     <p class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(232, 219, 217);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# <i class="fa fa-linkedin-square" aria-hidden="true"></i> <b>Yogesh Dagar</b>
# <br><br>Currently looking for skill endorsements (any form of help is highly appreciated)
#      </p></a>
#     <br>
#     <a class="w-para" href="https://github.com/itsmeyogesh22">
#     <h1 class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(232, 219, 217);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# <b><i class="fa fa-github" aria-hidden="true"></i> itsmeyogesh22</b>
# </h1>
# </a>
# <br>
#     <h1 class = 'w-para'
#        style = "
#                 font-family: Consolas,monaco,monospace;
#                 padding: 16px 17px;
#                 border: 4px solid #000;
#                 background-color: rgb(232, 219, 217);
#                 color: #000;
#                 font-size: 2rem;
#                 font-weight: 60;
#                 margin-left: 15px;
#                 margin-right: 15px;
#                 margin-bottom: 10px;
#                ">
# <b><i class="fa fa-envelope-square" aria-hidden="true"></i> dagary513@gmail.com</b>
# </h1>
# <br>
# </div>
# </div>
